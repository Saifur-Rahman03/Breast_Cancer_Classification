# %% [markdown]
# # Import Data

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
import tensorflow as tf
import keras
from keras import layers
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Breast Cancer Classification/t-Test-PCA-Rfe/'
data = pd.read_csv(file_path + 'rearranged_data_rfe_rf.csv')
data.columns
# Out:
# Index(['PCA 1', 'PCA 3', 'PCA 4', 'PCA 2', 'PCA 8', 'PCA 10', 'PCA 11',
#        'PCA 14', 'PCA 6', 'PCA 23', 'PCA 5', 'PCA 12', 'PCA 7', 'PCA 15',
#        'PCA 13', 'PCA 9', 'PCA 20', 'PCA 26', 'PCA 30', 'PCA 16', 'PCA 19',
#        'PCA 25', 'PCA 17', 'PCA 28', 'PCA 18', 'PCA 24', 'PCA 21', 'PCA 27',
#        'PCA 22', 'PCA 29', 'Class'],
#       dtype='object')

# %%
data.shape[1]
# Out:
# 31

# %% [markdown]
# # Select No. of Features

# %%
feat_dnn = 17

# %% [markdown]
# # DNN

# %%
# Load the dataset
#data = pd.read_csv('rearranged_data_rfe_rf.csv')

X = data.iloc[:, :feat_dnn].values # Features
y = data.iloc[:, -1].values # Labels

# Map 'B' to 0 and 'M' to 1
y_encoded = y.copy()
y_encoded = [0 if label == 'B' else 1 for label in y]

# Check the transformation
#print(y_encoded)
y = y_encoded

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=143017)

# %%
# Scaling the dataset
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train = scaling.transform(X_train)
X_test = scaling.transform(X_test)

# %%
# Build the DNN model
model = keras.Sequential(
    [
        layers.Dense(40, activation='relu', input_dim=X_train.shape[1]),
        layers.Dense(20, activation='relu'),
        layers.Dense(1, activation='sigmoid') # Binary classification
    ]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 40)                  │             720 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 20)                  │             820 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,561 (6.10 KB)
#  Trainable params: 1,561 (6.10 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(loss=tf.keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.keras',
                                              monitor='val_accuracy', mode='max',
                                              verbose=1)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
history = model.fit(X_train,
                    y_train,
                    validation_split=0.2,
                    batch_size = 10,
                    epochs = 15,
                    callbacks=[callback])
# Out:
# Epoch 1/15
# 20/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3289 - loss: 0.7341
# Epoch 1: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4345 - loss: 0.7133 - val_accuracy: 0.6484 - val_loss: 0.6462
# Epoch 2/15
# 35/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 0.6130
# Epoch 2: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6710 - loss: 0.6112 - val_accuracy: 0.6593 - val_loss: 0.5926
# Epoch 3/15
# 32/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7606 - loss: 0.5398
# Epoch 3: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7629 - loss: 0.5365 - val_accuracy: 0.7802 - val_loss: 0.5123
# Epoch 4/15
# 32/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8452 - loss: 0.4435
# Epoch 4: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8499 - loss: 0.4401 - val_accuracy: 0.8242 - val_loss: 0.4189
# Epoch 5/15
# 27/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8986 - loss: 0.3592
# Epoch 5: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9021 - loss: 0.3478 - val_accuracy: 0.8901 - val_loss: 0.3252
# Epoch 6/15
# 21/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9511 - loss: 0.2565
# Epoch 6: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9446 - loss: 0.2503 - val_accuracy: 0.9121 - val_loss: 0.2592
# Epoch 7/15
# 35/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.1846
# Epoch 7: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9694 - loss: 0.1846 - val_accuracy: 0.9231 - val_loss: 0.2190
# Epoch 8/15
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 1.0000 - loss: 0.1607
# Epoch 8: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9517 - loss: 0.1732 - val_accuracy: 0.9231 - val_loss: 0.2038
# Epoch 9/15
# 34/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1220
# Epoch 9: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9663 - loss: 0.1230 - val_accuracy: 0.9231 - val_loss: 0.1856
# Epoch 10/15
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9653 - loss: 0.1224
# Epoch 10: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9653 - loss: 0.1221 - val_accuracy: 0.9341 - val_loss: 0.1751
# Epoch 11/15
# 35/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9845 - loss: 0.0951
# Epoch 11: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9836 - loss: 0.0959 - val_accuracy: 0.9231 - val_loss: 0.1708
# Epoch 12/15
# 33/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9766 - loss: 0.1023
# Epoch 12: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9760 - loss: 0.1023 - val_accuracy: 0.9231 - val_loss: 0.1684
# Epoch 13/15
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9682 - loss: 0.0873
# Epoch 13: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.0876 - val_accuracy: 0.9341 - val_loss: 0.1692
# Epoch 14/15
# 29/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9860 - loss: 0.0722
# Epoch 14: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9834 - loss: 0.0765 - val_accuracy: 0.9231 - val_loss: 0.1715
# Epoch 15/15
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 15: saving model to best_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0643 - val_accuracy: 0.9341 - val_loss: 0.1688

# %% [markdown]
# Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Combined Accurac & Loss

# %%
# Plot the training and validation accuracy and loss over epochs
plt.figure(figsize=(10, 6), dpi=150)

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)

# Plot loss
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)

plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('Training and Validation Metrics', fontweight='bold')
plt.legend()
plt.grid(True)

# Save the figure
#plt.savefig('accuracy_loss_curve.png', dpi=300)
plt.show()

# %%
# Make predictions
y_pred = (model.predict(X_test) > 0.4).astype(int)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Printing confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix:\n", cm)
n_classes = cm.shape[0]
class_accuracy = []
for i in range(n_classes):
    class_accuracy.append(cm[i,i]/np.sum(cm[i,:]))
print("Accuracy of each class: ", class_accuracy)
# Out:
# Confusion matrix:
#  [[63  2]
#  [ 3 46]]
# Accuracy of each class:  [0.9692307692307692, 0.9387755102040817]

# %%
# Plotting confusion matrix
plt.figure(figsize=(16, 12))
plt.imshow(cm, interpolation='nearest', cmap='Oranges')
plt.title('Confusion matrix')
plt.colorbar()
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
tick_marks = np.arange(len(set(y)))
plt.xticks(tick_marks, sorted(set(y)))
plt.yticks(tick_marks, sorted(set(y)))
for i in range(len(cm)):
    for j in range(len(cm[0])):
        plt.annotate(str(cm[i][j]), xy=(j, i),
                     horizontalalignment='center',
                     verticalalignment='center',
                     color='white' if cm[i][j] > (0.5*cm.max()) else 'black',
                     fontsize=32)
plt.rcParams.update({'font.size': 24})
plt.savefig('cm-svm.png')
plt.show()

# %%
# Printing classification report
print("Classification report:\n", classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        65
#            1       0.96      0.94      0.95        49
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
# Calculating metrics
accuracy_svm = metrics.accuracy_score(y_test, y_pred)
precision_svm = metrics.precision_score(y_test, y_pred, average=None)
recall_svm = metrics.recall_score(y_test, y_pred, average=None)
f1_score_svm = metrics.f1_score(y_test, y_pred, average=None)

# %%
# Printing metrics rounded to two decimal points
print("Accuracy:", round(accuracy_svm, 4))
print("Precision:", [round(p, 4) for p in precision_svm], round(sum(precision_svm) / len(precision_svm), 4))
print("Recall:", [round(r, 4) for r in recall_svm], round(sum(recall_svm) / len(recall_svm), 4))
print("F1-Score:", [round(f, 4) for f in f1_score_svm], round(sum(f1_score_svm) / len(f1_score_svm), 4))
# Out:
# Accuracy: 0.9561
# Precision: [0.9545, 0.9583] 0.9564
# Recall: [0.9692, 0.9388] 0.954
# F1-Score: [0.9618, 0.9485] 0.9551
